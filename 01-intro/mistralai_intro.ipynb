# %%
import os
from dotenv import load_dotenv

from mistralai.client import MistralClient
from mistralai.models.chat_completion import ChatMessage

from pprint import pprint

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.environ["MISTRALAI_API_KEY"]
model = "mistral-large-latest"

# %%
client = MistralClient(api_key=api_key)

chat_response = client.chat(
    model=model,
    messages=[ChatMessage(role="user", 
                          content="What is the best French football player of this century?")]
)

# %%
pprint(chat_response.choices[0].message.content)
# Out:
# ('Determining the "best" French football player of this century can be '
#  'subjective and depends on various factors such as individual skills, '
#  'achievements, consistency, and impact on the game. However, two names often '
#  'come up in such discussions:\n'
#  '\n'
#  '1. Zinedine Zidane: Although his professional playing career ended in the '
#  'first half of this century, his impact is still widely recognized. He was '
#  'named the best European footballer of the past 50 years in the UEFA Golden '
#  'Jubilee Poll and won the FIFA World Player of the Year award three times.\n'
#  '\n'
#  '2. Thierry Henry: Known for his time at Arsenal and Barcelona, Henry is '
#  'considered one of the greatest strikers of all time. He was a key player for '
#  "France's successful national team in the early 21st century.\n"
#  '\n'
#  '3. More recently, players like Karim Benzema and Kylian Mbappé have also '
#  'made significant impacts. Mbappé, in particular, has already achieved a '
# ...

# %%
q = """How can I solve this warning? RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4) doesn't match a supported version!
  warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported"""

chat_response = client.chat(
    model=model,
    messages=[ChatMessage(role="user", 
                          content=q)]
)

pprint(chat_response.choices[0].message.content)
# Out:
# ('This warning is indicating that the versions of urllib3 and chardet you have '
#  'installed in your environment do not match the versions required by the '
#  'Requests library. To resolve this warning, you can upgrade or downgrade the '
#  'problematic libraries to versions that are compatible with Requests.\n'
#  '\n'
#  'First, you can try upgrading both libraries to the latest version using '
#  'pip:\n'
#  '```\n'
#  'pip install --upgrade urllib3 chardet\n'
#  '```\n'
#  "If upgrading both libraries doesn't resolve the warning, you can check the "
#  'Requests library documentation to determine which versions of urllib3 and '
#  'chardet are compatible with the version of Requests you are using. Then, you '
#  'can specify those versions when installing or upgrading the libraries:\n'
#  '```bash\n'
#  'pip install urllib3==<compatible_version> chardet==<compatible_version>\n'
#  '```\n'
#  'Replace `<compatible_version>` with the specific version number that is '
# ...
